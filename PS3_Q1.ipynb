# %% [markdown]
# Question 1
# Introduction:
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
# Occupations<br>
# Step 1. Import the necessary libraries
# <br>Step 2. Import the dataset from this address.
# <br>Step 3. Assign it to a variable called users
# <br>Step 4. Discover what is the mean age per occupation
# <br>Step 5. Discover the Male ratio per occupation and sort it from the most to the least
# <br>Step 6. For each occupation, calculate the minimum and maximum ages
# <br>Step 7. For each combination of occupation and sex, calculate the mean age
# <br>Step 8. For each occupation present the percentage of women and men

# %%
import pandas as pd

# %%
# Step 2 and 3: Import the dataset assign it to a variable called users
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
# Step 4. Discover what is the mean age per occupation
mean_age_per_occupation = users.groupby('occupation').age.mean()
print(mean_age_per_occupation)
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
def maleRatio(x):
    return x[x == 'M'].count() / x.count()

male_ratio_per_occupation = users.groupby('occupation').gender.apply(maleRatio).sort_values(ascending=False)
print(male_ratio_per_occupation)
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# Name: gender, dtype: float64

# %%
# Step 6. For each occupation, calculate the minimum and maximum ages
min_max_age_per_occupation = users.groupby('occupation').age.agg(['min', 'max'])
print(min_max_age_per_occupation)
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
# Step 7. For each combination of occupation and sex, calculate the mean age
mean_age_per_occupation_and_sex = users.groupby(['occupation', 'gender']).age.mean()
print(mean_age_per_occupation_and_sex)
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
# Step 8. For each occupation present the percentage of women and men
def percentageSex(x):
    return x.value_counts(normalize=True) * 100

percentage_sex_per_occupation = users.groupby('occupation').gender.apply(percentageSex).unstack()
print(percentage_sex_per_occupation)
# Out:
#                        F           M
# occupation
# administrator  45.569620   54.430380
# artist         46.428571   53.571429
# doctor               NaN  100.000000
# educator       27.368421   72.631579
# engineer        2.985075   97.014925
# entertainment  11.111111   88.888889
# executive       9.375000   90.625000
# healthcare     68.750000   31.250000
# homemaker      85.714286   14.285714
# lawyer         16.666667   83.333333
# librarian      56.862745   43.137255
# marketing      38.461538   61.538462
# none           44.444444   55.555556
# other          34.285714   65.714286
# programmer      9.090909   90.909091
# retired         7.142857   92.857143
# salesman       25.000000   75.000000
# scientist       9.677419   90.322581
# student        30.612245   69.387755
# technician      3.703704   96.296296
# writer         42.222222   57.777778
